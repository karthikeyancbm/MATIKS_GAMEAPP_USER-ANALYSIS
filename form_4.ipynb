# %%
import pandas as pd
import numpy as np
import re
import os
import warnings
warnings.filterwarnings('ignore')
import time
import math

# %%
file_path = r"C:\Users\DELL\Documents\eway\CHOHB.xlsm"

# Step 1: Load Excel file
xls = pd.ExcelFile(file_path)



# Step 2: Read last sheet
df= pd.read_excel(file_path)

print(xls.sheet_names)
# Out:
# ['CHOHB-203', 'CHOHB-212', 'CHOHB-215', 'CHOHB-231', 'CHOHB-233', 'CHOHB-235', 'CHOHB-238', 'CHOHB-249', 'CHOHB-250', 'CHOHB-251', 'CHOHB-252', 'CHOHB-253', 'CHOHB-258', 'CHOHB-264', 'CHOHB-261', 'CHOHB-260', 'CHOHB-262', 'CHOHB-259', 'CHOHB-275', 'CHOHB-276', 'CHOHB-277', 'CHOHB-281', 'CHOHB-282', 'CHOHB-283', 'CHOHB-284', 'CHOHB-285', 'CINRSB-1', 'CHOHB-313', 'CHOCAI-1', 'CHOHB-3131', 'CHOHB-314', 'CHOHB-315', 'CHOHB-319', 'CHOHB-320', 'CHOHB-321', 'CHOHB-322', 'CHOHB-324', 'CHOHB-325', 'CHOHB-326', 'CHOHB-328', 'CHOHB-329', 'CHOHB-316', 'CHOHB-317', 'CHOHB-313.', 'CHOHB-314.', 'CHOHB-318', 'CHOHB-323', 'CHOHB-327', 'CHOHB-330', 'CHOHB-332', 'CHOHB-331', 'CHOHB-333', 'CHOHB-336', 'CHOHB-337', 'CHOHB-335', 'CHOHB-334', 'CHOHB-338', 'CHOHB-339', 'CHOHB-340', 'CHOHB-341', 'CHOHB-342', 'CINHB-15', 'CINHB-14', 'CHOHB-343', 'CINHB-17', 'CHOHB-344', 'CHOHB-344 (2)', 'CINHB-22 (2)', 'CINHB-16', 'CINHB-18', 'CINHB-19', 'CINHB-20', 'CINHB-21', 'CINHB-22', 'chohb 340', 'chohb 341', 'chohb 342
# ...

# %%
file_path = r"C:\Users\DELL\Documents\eway\CHOHB.xlsm"

# Step 1: Load Excel file
xls = pd.ExcelFile(file_path)



# Step 2: Read last sheet
df= pd.read_excel(file_path,sheet_name = 'CHOHB-231',header=None)

df
# Out:
#                                                     0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                        BHIMA JEWELLERY MADURAI - HO
# 10             196 2ND FLOOR , SUBA SHRI ARUN COMPLEX
# 11                                   MADURAI - 625016
# 12                            GSTIN - 33AAIFB1068K1ZJ
# 13                                   Delivery Challan
# 14                               Delivery Challan No
# 15                                              Date
# ...

# %%
file_path = r"C:\Users\DELL\Documents\eway\city_files\trichy.xlsx"

# Step 1: Load Excel file
xls = pd.ExcelFile(file_path)



# Step 2: Read last sheet
df= pd.read_excel(file_path, sheet_name=xls.sheet_names[-1],header=None)

df
# Out:
#                                                     0  \
# 0                        BHIMA JEWELLERY MADURAI - HO
# 1              196 2ND FLOOR , SUBA SHRI ARUN COMPLEX
# 2                                    MADURAI - 625016
# 3                             GSTIN - 33AAIFB1068K1ZJ
# 4                                    Delivery Challan
# 5                                Delivery Challan No
# 6                                               Date
# 7                             Supporting Document No
# 8                           Supporting Document Date
# 9   Details of the \nRecipient/Consignee ( Job Wor...
# 10                                               Name
# 11                             Address with \nPincode
# 12                                                NaN
# 13                                                NaN
# 14                                             State
# 15                                         State Code
# ...

# %%
file_path = r"C:\Users\DELL\Documents\eway\city_files\trichy.xlsx"

# Step 1: Load Excel file
xls = pd.ExcelFile(file_path)

# Step 2: Read last sheet
df= pd.read_excel(file_path, sheet_name=xls.sheet_names[-1],header=None)

df
# Out:
#                                                     0  \
# 0                        BHIMA JEWELLERY MADURAI - HO
# 1              196 2ND FLOOR , SUBA SHRI ARUN COMPLEX
# 2                                    MADURAI - 625016
# 3                             GSTIN - 33AAIFB1068K1ZJ
# 4                                    Delivery Challan
# 5                                Delivery Challan No
# 6                                               Date
# 7                             Supporting Document No
# 8                           Supporting Document Date
# 9   Details of the \nRecipient/Consignee ( Job Wor...
# 10                                               Name
# 11                             Address with \nPincode
# 12                                                NaN
# 13                                                NaN
# 14                                             State
# 15                                         State Code
# ...

# %%
df = df.dropna(how='all',axis=0)
df = df.dropna(how='all',axis=1)
df =df.reset_index(drop=True)

# %%
df
# Out:
#                                                     0  \
# 0                        BHIMA JEWELLERY MADURAI - HO
# 1              196 2ND FLOOR , SUBA SHRI ARUN COMPLEX
# 2                                    MADURAI - 625016
# 3                             GSTIN - 33AAIFB1068K1ZJ
# 4                                    Delivery Challan
# 5                                Delivery Challan No
# 6                                               Date
# 7                             Supporting Document No
# 8                           Supporting Document Date
# 9   Details of the \nRecipient/Consignee ( Job Wor...
# 10                                               Name
# 11                             Address with \nPincode
# 12                                                NaN
# 13                                                NaN
# 14                                             State
# 15                                         State Code
# ...

# %%
df.iloc[:,0]
# Out:
# 0                          BHIMA JEWELLERY MADURAI - HO
# 1                196 2ND FLOOR , SUBA SHRI ARUN COMPLEX
# 2                                      MADURAI - 625016
# 3                               GSTIN - 33AAIFB1068K1ZJ
# 4                                      Delivery Challan
# 5                                  Delivery Challan No
# 6                                                 Date
# 7                               Supporting Document No
# 8                             Supporting Document Date
# 9     Details of the \nRecipient/Consignee ( Job Wor...
# 10                                                 Name
# 11                               Address with \nPincode
# 12                                                  NaN
# 13                                                  NaN
# 14                                               State
# 15                                           State Code
# 16                                                GSTIN
# ...

# %%
df.iloc[:,0] = df.iloc[:,0].astype(str).str.replace(r"[\n\t]+"," ",regex=True).str.strip()

# %%
for i in df.columns:
    df.iloc[:,i] = df.iloc[:,i].astype(str).str.replace(r"[\n\t]+"," ",regex=True).str.strip()

# %%
df.unstack().reset_index()
# Out:
#      level_0  level_1                                       0
# 0          0        0            BHIMA JEWELLERY MADURAI - HO
# 1          0        1  196 2ND FLOOR , SUBA SHRI ARUN COMPLEX
# 2          0        2                        MADURAI - 625016
# 3          0        3                 GSTIN - 33AAIFB1068K1ZJ
# 4          0        4                        Delivery Challan
# ..       ...      ...                                     ...
# 243        7       26                                       0
# 244        7       27                                       0
# 245        7       28                                       0
# 246        7       29                                  184491
# 247        7       30                                     nan
#
# [248 rows x 3 columns]

# %%
df.set_index(0,inplace=True)

# %%
df
# Out:
#                                                                                                  1  \
# 0
# BHIMA JEWELLERY MADURAI - HO                                                                   nan
# 196 2ND FLOOR , SUBA SHRI ARUN COMPLEX                                                         nan
# MADURAI - 625016                                                                               nan
# GSTIN - 33AAIFB1068K1ZJ                                                                        nan
# Delivery Challan                                                                               nan
# Delivery Challan No                                                                            nan
# Date                                                                                           nan
# Supporting Document No                                                                         nan
# ...

# %%
df.loc['Name',2]
# Out:
# 'BHIMA JEWELLERY TRICHY'

# %%
dry = {k:v for k,v in df.iterrows()}
dry.keys
# Out:
# <function dict.keys()>

# %%
for k,v in df.iterrows():
    if v.any() == 'nan':
        df.drop(inplace=True).any()
    print(k,v)
# Out:
# BHIMA JEWELLERY MADURAI - HO 1    nan
# 2    nan
# 3    nan
# 4    nan
# 5    nan
# 6    nan
# 7    nan
# Name: BHIMA JEWELLERY MADURAI - HO, dtype: object
# 196 2ND FLOOR , SUBA SHRI ARUN COMPLEX 1    nan
# 2    nan
# 3    nan
# 4    nan
# 5    nan
# 6    nan
# 7    nan
# Name: 196 2ND FLOOR , SUBA SHRI ARUN COMPLEX, dtype: object
# MADURAI - 625016 1    nan
# 2    nan
# 3    nan
# 4    nan
# 5    nan
# 6    nan
# 7    nan
# Name: MADURAI - 625016, dtype: object
# GSTIN - 33AAIFB1068K1ZJ 1    nan
# 2    nan
# 3    nan
# 4    nan
# 5    nan
# 6    nan
# 7    nan
# Name: GSTIN - 33AAIFB1068K1ZJ, dtype: object
# Delivery Challan 1    nan
# 2    nan
# 3    nan
# 4    nan
# 5    nan
# 6    nan
# 7    nan
# Name: Delivery Challan, dtype: object
# Delivery Challan No 1                 nan
# 2    DC - CHOHB -1789
# 3                 nan
# 4                 nan
# 5                 nan
# 6                 nan
# 7                 nan
# Name: Delivery Challan No, dtype: object
# ...

# %% [markdown]
# #to_office

# %%
df
# Out:
#                                                                                                  1  \
# 0
# BHIMA JEWELLERY MADURAI - HO                                                                   nan
# 196 2ND FLOOR , SUBA SHRI ARUN COMPLEX                                                         nan
# MADURAI - 625016                                                                               nan
# GSTIN - 33AAIFB1068K1ZJ                                                                        nan
# Delivery Challan                                                                               nan
# Delivery Challan No                                                                            nan
# Date                                                                                           nan
# Supporting Document No                                                                         nan
# ...

# %%
for i in df.index:
    if i == 'Name':
        to_office = df.loc[i,2].strip()
    
to_office
# Out:
# 'BHIMA JEWELLERY TRICHY'

# %%
for i in df.index:
    if i == 'Address with  Pincode':
        to_office_add_1 = df.loc[i,2].strip()
        to_office_add_1 = re.sub(r'[^A-Za-z0-9]+'," ",to_office_add_1)
to_office_add_1
# Out:
# '32 33 CHINNA KADAI VEEDHI'

# %%
for i in df.index:
    if i == 'Address with  Pincode':
        df = df.reset_index()
        to_office_add_2= df.iloc[12,2].strip()
        df.set_index(0,inplace=True)
to_office_add_2
# Out:
# 'NSB ROAD'

# %%
city_lst = ['MADURAI', 'RAJPALAYAM', 'DINDIGUL', 'TRICHY', 'SALEM','RAJAPALYAM','RAJAPALAYAM','DINDUGAL']

# %%
for i in df.index:
    if i == 'Address with  Pincode':
        df = df.reset_index()
        x_name= df.iloc[13,2].strip()
        df.set_index(0,inplace=True)
x_name
# Out:
# 'TRICHY'

# %%
if to_office_city in city_lst:
    to_office_add_2 = x_name
else:
    to_office_pin = x_name

# %%
to_office_pin
# Out:
# 'TRICHY'

# %%
df
# Out:
#                                                                                                  1  \
# 0
# BHIMA JEWELLERY MADURAI - HO                                                                   nan
# 196 2ND FLOOR , SUBA SHRI ARUN COMPLEX                                                         nan
# MADURAI - 625016                                                                               nan
# GSTIN - 33AAIFB1068K1ZJ                                                                        nan
# Delivery Challan                                                                               nan
# Delivery Challan No                                                                            nan
# Date                                                                                           nan
# Supporting Document No                                                                         nan
# ...
