# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\ASUS\Documents\GUVI ZEN CLASSES\MAINT BOOT\Bengaluru_House_Data.csv")
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=13320, step=1)

# %% [markdown]
# One row is a tuple.

# %%
df = pd.read_csv(r"C:\Users\ASUS\Documents\GUVI ZEN CLASSES\MAINT BOOT\ds_salaries.csv")
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=607, step=1)

# %%
df = pd.read_excel(r"C:\Users\ASUS\Documents\GUVI ZEN CLASSES\MAINT BOOT\IndStartUpFunding.xlsx")
df
# Out:
#       Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0         1  2020-01-09 00:00:00                        BYJU’S
# 1         2  2020-01-13 00:00:00                        Shuttl
# 2         3  2020-01-09 00:00:00                     Mamaearth
# 3         4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4         5  2020-01-02 00:00:00                        Fashor
# ...     ...                  ...                           ...
# 3039   3040  2015-01-29 00:00:00                    Printvenue
# 3040   3041  2015-01-29 00:00:00                      Graphene
# 3041   3042  2015-01-30 00:00:00                Mad Street Den
# 3042   3043  2015-01-30 00:00:00                     Simplotel
# 3043   3044  2015-01-31 00:00:00              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3044, step=1)

# %%
# to know the name of the columns
df.columns
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentType',
#        'Amount in USD', 'Remarks'],
#       dtype='object')

# %%
# column access
# to get the data of particular column
df['Startup Name']
# Out:
# 0                             BYJU’S
# 1                             Shuttl
# 2                          Mamaearth
# 3       https://www.wealthbucket.in/
# 4                             Fashor
#                     ...
# 3039                      Printvenue
# 3040                        Graphene
# 3041                  Mad Street Den
# 3042                       Simplotel
# 3043                couponmachine.in
# Name: Startup Name, Length: 3044, dtype: object

# %%
df['Industry Vertical']
# Out:
# 0                    E-Tech
# 1            Transportation
# 2                E-commerce
# 3                   FinTech
# 4       Fashion and Apparel
#                ...
# 3039                    NaN
# 3040                    NaN
# 3041                    NaN
# 3042                    NaN
# 3043                    NaN
# Name: Industry Vertical, Length: 3044, dtype: object

# %%
# to get information from multiple columns together - you need to pass a list of column names inside the square bracket.
df[['Startup Name','City  Location','Amount in USD']]
# Out:
#                       Startup Name City  Location Amount in USD
# 0                           BYJU’S      Bengaluru     200000000
# 1                           Shuttl        Gurgaon       8048394
# 2                        Mamaearth      Bengaluru      18358860
# 3     https://www.wealthbucket.in/      New Delhi       3000000
# 4                           Fashor         Mumbai       1800000
# ...                            ...            ...           ...
# 3039                    Printvenue            NaN       4500000
# 3040                      Graphene            NaN        825000
# 3041                Mad Street Den            NaN       1500000
# 3042                     Simplotel            NaN           NaN
# 3043              couponmachine.in            NaN        140000
#
# [3044 rows x 3 columns]

# %%
# to get the column name based on index position
df.columns[2]
# Out:
# 'Startup Name'

# %%
df[df.columns[2]]
# Out:
# 0                             BYJU’S
# 1                             Shuttl
# 2                          Mamaearth
# 3       https://www.wealthbucket.in/
# 4                             Fashor
#                     ...
# 3039                      Printvenue
# 3040                        Graphene
# 3041                  Mad Street Den
# 3042                       Simplotel
# 3043                couponmachine.in
# Name: Startup Name, Length: 3044, dtype: object

# %%
df[df.columns[5]]
# Out:
# 0       Bengaluru
# 1         Gurgaon
# 2       Bengaluru
# 3       New Delhi
# 4          Mumbai
#           ...
# 3039          NaN
# 3040          NaN
# 3041          NaN
# 3042          NaN
# 3043          NaN
# Name: City  Location, Length: 3044, dtype: object

# %%
df[[df.columns[3],df.columns[5]]]
# Out:
#         Industry Vertical City  Location
# 0                  E-Tech      Bengaluru
# 1          Transportation        Gurgaon
# 2              E-commerce      Bengaluru
# 3                 FinTech      New Delhi
# 4     Fashion and Apparel         Mumbai
# ...                   ...            ...
# 3039                  NaN            NaN
# 3040                  NaN            NaN
# 3041                  NaN            NaN
# 3042                  NaN            NaN
# 3043                  NaN            NaN
#
# [3044 rows x 2 columns]

# %%
df[df.columns[0:5]]
# Out:
#       Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0         1  2020-01-09 00:00:00                        BYJU’S
# 1         2  2020-01-13 00:00:00                        Shuttl
# 2         3  2020-01-09 00:00:00                     Mamaearth
# 3         4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4         5  2020-01-02 00:00:00                        Fashor
# ...     ...                  ...                           ...
# 3039   3040  2015-01-29 00:00:00                    Printvenue
# 3040   3041  2015-01-29 00:00:00                      Graphene
# 3041   3042  2015-01-30 00:00:00                Mad Street Den
# 3042   3043  2015-01-30 00:00:00                     Simplotel
# 3043   3044  2015-01-31 00:00:00              couponmachine.in
#
#         Industry Vertical                            SubVertical
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# ...

# %%
df[df.columns[[3,5]]]
# Out:
#         Industry Vertical City  Location
# 0                  E-Tech      Bengaluru
# 1          Transportation        Gurgaon
# 2              E-commerce      Bengaluru
# 3                 FinTech      New Delhi
# 4     Fashion and Apparel         Mumbai
# ...                   ...            ...
# 3039                  NaN            NaN
# 3040                  NaN            NaN
# 3041                  NaN            NaN
# 3042                  NaN            NaN
# 3043                  NaN            NaN
#
# [3044 rows x 2 columns]

# %% [markdown]
# when we have a data from single column,we call that as 'Series'.

# %%
data1 = df['Startup Name']
type(data1)
# Out:
# pandas.core.series.Series

# %%
data2 = df[['Startup Name','City  Location']]
type(data2)
# Out:
# pandas.core.frame.DataFrame

# %%
data3 = df[['City  Location']]
type(data3)
# Out:
# pandas.core.frame.DataFrame

# %%
# to access row 'loc' is used. loc = location In loc - last index is included for others last index is excluded
df.loc[0]
# Out:
# Sr No                                      1
# Date dd/mm/yyyy          2020-01-09 00:00:00
# Startup Name                          BYJU’S
# Industry Vertical                     E-Tech
# SubVertical                       E-learning
# City  Location                     Bengaluru
# Investors Name       Tiger Global Management
# InvestmentType          Private Equity Round
# Amount in USD                      200000000
# Remarks                                  NaN
# Name: 0, dtype: object

# %%
df.loc[2]
# Out:
# Sr No                                                    3
# Date dd/mm/yyyy                        2020-01-09 00:00:00
# Startup Name                                     Mamaearth
# Industry Vertical                               E-commerce
# SubVertical          Retailer of baby and toddler products
# City  Location                                   Bengaluru
# Investors Name                       Sequoia Capital India
# InvestmentType                                    Series B
# Amount in USD                                     18358860
# Remarks                                                NaN
# Name: 2, dtype: object

# %%
df.loc[[0,2]]
# Out:
#    Sr No      Date dd/mm/yyyy Startup Name Industry Vertical  \
# 0      1  2020-01-09 00:00:00       BYJU’S            E-Tech
# 2      3  2020-01-09 00:00:00    Mamaearth        E-commerce
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 2  Retailer of baby and toddler products      Bengaluru
#
#             Investors Name        InvestmentType Amount in USD Remarks
# 0  Tiger Global Management  Private Equity Round     200000000     NaN
# 2    Sequoia Capital India              Series B      18358860     NaN

# %%
df.loc[1:5]
# Out:
#    Sr No      Date dd/mm/yyyy                  Startup Name  \
# 1      2  2020-01-13 00:00:00                        Shuttl
# 2      3  2020-01-09 00:00:00                     Mamaearth
# 3      4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4      5  2020-01-02 00:00:00                        Fashor
# 5      6  2020-01-13 00:00:00                         Pando
#
#      Industry Vertical                               SubVertical  \
# 1       Transportation                 App based shuttle service
# 2           E-commerce     Retailer of baby and toddler products
# 3              FinTech                         Online Investment
# 4  Fashion and Apparel               Embroiled Clothes For Women
# 5            Logistics  Open-market, freight management platform
#
#   City  Location             Investors Name InvestmentType Amount in USD  \
# 1        Gurgaon  Susquehanna Growth Equity       Series C       8048394
# ...

# %%
df.loc[0:10:2] # 2 is step size 0+2 =2,2+2=4,4+2=6
# Out:
#     Sr No      Date dd/mm/yyyy Startup Name    Industry Vertical  \
# 0       1  2020-01-09 00:00:00       BYJU’S               E-Tech
# 2       3  2020-01-09 00:00:00    Mamaearth           E-commerce
# 4       5  2020-01-02 00:00:00       Fashor  Fashion and Apparel
# 6       7  2020-01-10 00:00:00       Zomato          Hospitality
# 8       9  2019-12-06 00:00:00     CarDekho           E-Commerce
# 10     11  2019-12-13 00:00:00       Rivigo           Technology
#
#                               SubVertical City  Location  \
# 0                              E-learning      Bengaluru
# 2   Retailer of baby and toddler products      Bengaluru
# 4             Embroiled Clothes For Women         Mumbai
# 6           Online Food Delivery Platform        Gurgaon
# 8                              Automobile        Gurgaon
# 10       Logistics Services and Solutions        Gurgaon
#
#                                   Investors Name        InvestmentType  \
# ...

# %%
df.loc[5:10,df.columns[2:6]]
# Out:
#     Startup Name Industry Vertical                               SubVertical  \
# 5          Pando         Logistics  Open-market, freight management platform
# 6         Zomato       Hospitality             Online Food Delivery Platform
# 7         Ecozen        Technology                                  Agritech
# 8       CarDekho        E-Commerce                                Automobile
# 9   Dhruva Space         Aerospace                   Satellite Communication
# 10        Rivigo        Technology          Logistics Services and Solutions
#
#    City  Location
# 5         Chennai
# 6         Gurgaon
# 7            Pune
# 8         Gurgaon
# 9       Bengaluru
# 10        Gurgaon

# %%
df.columns
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentType',
#        'Amount in USD', 'Remarks'],
#       dtype='object')

# %%
df.loc[5:10,['Startup Name','Industry Vertical','SubVertical','City  Location']]
# Out:
#     Startup Name Industry Vertical                               SubVertical  \
# 5          Pando         Logistics  Open-market, freight management platform
# 6         Zomato       Hospitality             Online Food Delivery Platform
# 7         Ecozen        Technology                                  Agritech
# 8       CarDekho        E-Commerce                                Automobile
# 9   Dhruva Space         Aerospace                   Satellite Communication
# 10        Rivigo        Technology          Logistics Services and Solutions
#
#    City  Location
# 5         Chennai
# 6         Gurgaon
# 7            Pune
# 8         Gurgaon
# 9       Bengaluru
# 10        Gurgaon

# %%
# when using iloc the last index is excluded.but while using loc,the last index in included.
df.iloc[5:11,2:6]
# Out:
#     Startup Name Industry Vertical                               SubVertical  \
# 5          Pando         Logistics  Open-market, freight management platform
# 6         Zomato       Hospitality             Online Food Delivery Platform
# 7         Ecozen        Technology                                  Agritech
# 8       CarDekho        E-Commerce                                Automobile
# 9   Dhruva Space         Aerospace                   Satellite Communication
# 10        Rivigo        Technology          Logistics Services and Solutions
#
#    City  Location
# 5         Chennai
# 6         Gurgaon
# 7            Pune
# 8         Gurgaon
# 9       Bengaluru
# 10        Gurgaon

# %%
## 1.first get columns df[df.columns[2:6]]
## 2.then get rows using loc --> loc[5:10]

df[df.columns[2:6]].loc[5:10]
# Out:
#     Startup Name Industry Vertical                               SubVertical  \
# 5          Pando         Logistics  Open-market, freight management platform
# 6         Zomato       Hospitality             Online Food Delivery Platform
# 7         Ecozen        Technology                                  Agritech
# 8       CarDekho        E-Commerce                                Automobile
# 9   Dhruva Space         Aerospace                   Satellite Communication
# 10        Rivigo        Technology          Logistics Services and Solutions
#
#    City  Location
# 5         Chennai
# 6         Gurgaon
# 7            Pune
# 8         Gurgaon
# 9       Bengaluru
# 10        Gurgaon

# %%
df[df.columns[3:8]].loc[5:10]
# Out:
#    Industry Vertical                               SubVertical City  Location  \
# 5          Logistics  Open-market, freight management platform        Chennai
# 6        Hospitality             Online Food Delivery Platform        Gurgaon
# 7         Technology                                  Agritech           Pune
# 8         E-Commerce                                Automobile        Gurgaon
# 9          Aerospace                   Satellite Communication      Bengaluru
# 10        Technology          Logistics Services and Solutions        Gurgaon
#
#                                   Investors Name        InvestmentType
# 5                              Chiratae Ventures              Series A
# 6                                  Ant Financial  Private Equity Round
# 7                    Sathguru Catalyzer Advisors              Series A
# 8                    Ping An Global Voyager Fund              Series D
# ...

# %%
df.iloc[5:11,3:8]
# Out:
#    Industry Vertical                               SubVertical City  Location  \
# 5          Logistics  Open-market, freight management platform        Chennai
# 6        Hospitality             Online Food Delivery Platform        Gurgaon
# 7         Technology                                  Agritech           Pune
# 8         E-Commerce                                Automobile        Gurgaon
# 9          Aerospace                   Satellite Communication      Bengaluru
# 10        Technology          Logistics Services and Solutions        Gurgaon
#
#                                   Investors Name        InvestmentType
# 5                              Chiratae Ventures              Series A
# 6                                  Ant Financial  Private Equity Round
# 7                    Sathguru Catalyzer Advisors              Series A
# 8                    Ping An Global Voyager Fund              Series D
# ...

# %%
df.head() # you get first 5 rows
# Out:
#    Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0      1  2020-01-09 00:00:00                        BYJU’S
# 1      2  2020-01-13 00:00:00                        Shuttl
# 2      3  2020-01-09 00:00:00                     Mamaearth
# 3      4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4      5  2020-01-02 00:00:00                        Fashor
#
#      Industry Vertical                            SubVertical City  Location  \
# 0               E-Tech                             E-learning      Bengaluru
# 1       Transportation              App based shuttle service        Gurgaon
# 2           E-commerce  Retailer of baby and toddler products      Bengaluru
# 3              FinTech                      Online Investment      New Delhi
# 4  Fashion and Apparel            Embroiled Clothes For Women         Mumbai
#
#               Investors Name        InvestmentType Amount in USD Remarks
# ...

# %%
df.tail() ## you get the last five rows
# Out:
#       Sr No      Date dd/mm/yyyy      Startup Name Industry Vertical  \
# 3039   3040  2015-01-29 00:00:00        Printvenue               NaN
# 3040   3041  2015-01-29 00:00:00          Graphene               NaN
# 3041   3042  2015-01-30 00:00:00    Mad Street Den               NaN
# 3042   3043  2015-01-30 00:00:00         Simplotel               NaN
# 3043   3044  2015-01-31 00:00:00  couponmachine.in               NaN
#
#      SubVertical City  Location                     Investors Name  \
# 3039         NaN            NaN        Asia Pacific Internet Group
# 3040         NaN            NaN                     KARSEMVEN Fund
# 3041         NaN            NaN     Exfinity Fund, GrowX Ventures.
# 3042         NaN            NaN                         MakeMyTrip
# 3043         NaN            NaN  UK based Group of Angel Investors
#
#       InvestmentType Amount in USD                            Remarks
# 3039  Private Equity       4500000                                NaN
# ...

# %%
df.head(3) ## the 3 denotes how many rows the user want to get...the number is choice of the user.
# Out:
#    Sr No      Date dd/mm/yyyy Startup Name Industry Vertical  \
# 0      1  2020-01-09 00:00:00       BYJU’S            E-Tech
# 1      2  2020-01-13 00:00:00       Shuttl    Transportation
# 2      3  2020-01-09 00:00:00    Mamaearth        E-commerce
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
#
#               Investors Name        InvestmentType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round     200000000     NaN
# 1  Susquehanna Growth Equity              Series C       8048394     NaN
# 2      Sequoia Capital India              Series B      18358860     NaN

# %%
df.tail(3)
# Out:
#       Sr No      Date dd/mm/yyyy      Startup Name Industry Vertical  \
# 3041   3042  2015-01-30 00:00:00    Mad Street Den               NaN
# 3042   3043  2015-01-30 00:00:00         Simplotel               NaN
# 3043   3044  2015-01-31 00:00:00  couponmachine.in               NaN
#
#      SubVertical City  Location                     Investors Name  \
# 3041         NaN            NaN     Exfinity Fund, GrowX Ventures.
# 3042         NaN            NaN                         MakeMyTrip
# 3043         NaN            NaN  UK based Group of Angel Investors
#
#       InvestmentType Amount in USD                            Remarks
# 3041  Private Equity       1500000                                NaN
# 3042  Private Equity           NaN  Strategic Funding, Minority stake
# 3043    Seed Funding        140000                                NaN

# %%
df.describe() ## if your columsn have numerical values,this function will give the listed features.it works on numerical columns 
#only not on strings.
# Out:
#              Sr No
# count  3044.000000
# mean   1522.500000
# std     878.871435
# min       1.000000
# 25%     761.750000
# 50%    1522.500000
# 75%    2283.250000
# max    3044.000000

# %%
df.info() ## object = consists of either string data type or mixed data type.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentType     3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
df[['Startup Name']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Startup Name  3044 non-null   object
# dtypes: object(1)
# memory usage: 23.9+ KB

# %%
## creating data frame
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['Name'] = ['a','b','c','d','e','f']
df
# Out:
#   Name
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# 5    f

# %%
df['Age'] = [25,26,27,28,29,30]
df
# Out:
#   Name  Age
# 0    a   25
# 1    b   26
# 2    c   27
# 3    d   28
# 4    e   29
# 5    f   30

# %%
df['Marks'] = [45,' ',65,82,93,82]
df
# Out:
#   Name  Age Marks
# 0    a   25    45
# 1    b   26
# 2    c   27    65
# 3    d   28    82
# 4    e   29    93
# 5    f   30    82

# %%
df
# Out:
#   Name  Age Marks
# 0    a   25    45
# 1    b   26
# 2    c   27    65
# 3    d   28    82
# 4    e   29    93
# 5    f   30    82

# %%
df['email'] = ['vs@gmail.com','sk@gmail.com','ab@gmail.com','ed@gmail.com','de@gmail.com','xz@gmail.com']
df
# Out:
#   Name  Age Marks         email
# 0    a   25    45  vs@gmail.com
# 1    b   26        sk@gmail.com
# 2    c   27    65  ab@gmail.com
# 3    d   28    82  ed@gmail.com
# 4    e   29    93  de@gmail.com
# 5    f   30    82  xz@gmail.com

# %%
## to delete a column axis = 1 ---> column,axis = 0 ----> row x-axis -->0,y -axis -->1
df.drop(['Marks'],axis=1)
# Out:
#   Name  Age         email
# 0    a   25  vs@gmail.com
# 1    b   26  sk@gmail.com
# 2    c   27  ab@gmail.com
# 3    d   28  ed@gmail.com
# 4    e   29  de@gmail.com
# 5    f   30  xz@gmail.com

# %%
df = df.drop(['Marks'],axis=1)

# %%
df
# Out:
#   Name  Age         email
# 0    a   25  vs@gmail.com
# 1    b   26  sk@gmail.com
# 2    c   27  ab@gmail.com
# 3    d   28  ed@gmail.com
# 4    e   29  de@gmail.com
# 5    f   30  xz@gmail.com

# %%
df.drop(['Age'],axis=1,inplace=True)

# %%
df
# Out:
#   Name         email
# 0    a  vs@gmail.com
# 1    b  sk@gmail.com
# 2    c  ab@gmail.com
# 3    d  ed@gmail.com
# 4    e  de@gmail.com
# 5    f  xz@gmail.com

# %%
df = pd.read_excel(r"C:\Users\ASUS\Documents\GUVI ZEN CLASSES\MAINT BOOT\IndStartUpFunding.xlsx")
df.head()
# Out:
#    Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0      1  2020-01-09 00:00:00                        BYJU’S
# 1      2  2020-01-13 00:00:00                        Shuttl
# 2      3  2020-01-09 00:00:00                     Mamaearth
# 3      4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4      5  2020-01-02 00:00:00                        Fashor
#
#      Industry Vertical                            SubVertical City  Location  \
# 0               E-Tech                             E-learning      Bengaluru
# 1       Transportation              App based shuttle service        Gurgaon
# 2           E-commerce  Retailer of baby and toddler products      Bengaluru
# 3              FinTech                      Online Investment      New Delhi
# 4  Fashion and Apparel            Embroiled Clothes For Women         Mumbai
#
#               Investors Name        InvestmentType Amount in USD Remarks
# ...

# %%
df.columns
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentType',
#        'Amount in USD', 'Remarks'],
#       dtype='object')

# %%
df.drop(['Amount in USD'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0      1  2020-01-09 00:00:00                        BYJU’S
# 1      2  2020-01-13 00:00:00                        Shuttl
# 2      3  2020-01-09 00:00:00                     Mamaearth
# 3      4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4      5  2020-01-02 00:00:00                        Fashor
#
#      Industry Vertical                            SubVertical City  Location  \
# 0               E-Tech                             E-learning      Bengaluru
# 1       Transportation              App based shuttle service        Gurgaon
# 2           E-commerce  Retailer of baby and toddler products      Bengaluru
# 3              FinTech                      Online Investment      New Delhi
# 4  Fashion and Apparel            Embroiled Clothes For Women         Mumbai
#
#               Investors Name        InvestmentType Remarks
# 0    Tiger Global Management  Private Equity Round     NaN
# ...

# %%
df = df.drop(['Remarks'],axis=1)

# %%
df.head()
# Out:
#    Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0      1  2020-01-09 00:00:00                        BYJU’S
# 1      2  2020-01-13 00:00:00                        Shuttl
# 2      3  2020-01-09 00:00:00                     Mamaearth
# 3      4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4      5  2020-01-02 00:00:00                        Fashor
#
#      Industry Vertical                            SubVertical City  Location  \
# 0               E-Tech                             E-learning      Bengaluru
# 1       Transportation              App based shuttle service        Gurgaon
# 2           E-commerce  Retailer of baby and toddler products      Bengaluru
# 3              FinTech                      Online Investment      New Delhi
# 4  Fashion and Apparel            Embroiled Clothes For Women         Mumbai
#
#               Investors Name        InvestmentType
# 0    Tiger Global Management  Private Equity Round
# ...

# %%
df.drop(['SubVertical','Investors Name'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0      1  2020-01-09 00:00:00                        BYJU’S
# 1      2  2020-01-13 00:00:00                        Shuttl
# 2      3  2020-01-09 00:00:00                     Mamaearth
# 3      4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4      5  2020-01-02 00:00:00                        Fashor
#
#      Industry Vertical City  Location        InvestmentType
# 0               E-Tech      Bengaluru  Private Equity Round
# 1       Transportation        Gurgaon              Series C
# 2           E-commerce      Bengaluru              Series B
# 3              FinTech      New Delhi          Pre-series A
# 4  Fashion and Apparel         Mumbai            Seed Round

# %%
df = pd.read_csv(r"C:\Users\ASUS\Documents\GUVI ZEN CLASSES\MAINT BOOT\Ecommerce_Sales_Prediction_Dataset.csv")
df
# Out:
#            Date Product_Category   Price  Discount Customer_Segment  \
# 0    01-01-2023           Sports  932.80     35.82       Occasional
# 1    02-01-2023             Toys  569.48      3.60          Premium
# 2    03-01-2023       Home Decor  699.68      3.56          Premium
# 3    04-01-2023             Toys  923.27      0.61          Premium
# 4    05-01-2023             Toys  710.17     47.83          Premium
# ..          ...              ...     ...       ...              ...
# 995  22-09-2025          Fashion  740.06     49.06          Regular
# 996  23-09-2025      Electronics  517.10     28.48          Premium
# 997  24-09-2025      Electronics  683.43     12.98       Occasional
# 998  25-09-2025           Sports   51.26     21.85       Occasional
# 999  26-09-2025       Home Decor   93.94     29.68          Regular
#
#      Marketing_Spend  Units_Sold
# 0            6780.38          32
# 1            6807.56          16
# 2            3793.91          27
# ...

# %%
df[df.columns[2:4]].loc[2:10]
# Out:
#      Price  Discount
# 2   699.68      3.56
# 3   923.27      0.61
# 4   710.17     47.83
# 5   161.01     36.88
# 6   580.53     17.66
# 7   610.65     14.83
# 8   429.89     17.49
# 9   739.08     38.73
# 10  935.02     33.07

# %%
df.iloc[2:11,2:4]
# Out:
#      Price  Discount
# 2   699.68      3.56
# 3   923.27      0.61
# 4   710.17     47.83
# 5   161.01     36.88
# 6   580.53     17.66
# 7   610.65     14.83
# 8   429.89     17.49
# 9   739.08     38.73
# 10  935.02     33.07

# %%
df
# Out:
#            Date Product_Category   Price  Discount Customer_Segment  \
# 0    01-01-2023           Sports  932.80     35.82       Occasional
# 1    02-01-2023             Toys  569.48      3.60          Premium
# 2    03-01-2023       Home Decor  699.68      3.56          Premium
# 3    04-01-2023             Toys  923.27      0.61          Premium
# 4    05-01-2023             Toys  710.17     47.83          Premium
# ..          ...              ...     ...       ...              ...
# 995  22-09-2025          Fashion  740.06     49.06          Regular
# 996  23-09-2025      Electronics  517.10     28.48          Premium
# 997  24-09-2025      Electronics  683.43     12.98       Occasional
# 998  25-09-2025           Sports   51.26     21.85       Occasional
# 999  26-09-2025       Home Decor   93.94     29.68          Regular
#
#      Marketing_Spend  Units_Sold
# 0            6780.38          32
# 1            6807.56          16
# 2            3793.91          27
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = df['Price'].tolist()
y = df['Units_Sold'].tolist()

plt.scatter(x,y,color='red')
plt.xlabel('Price')
plt.ylabel('Units_sold')
plt.title('Price vs Sales')
plt.show()
